# %% [markdown]
# #IMPORTING LIBRARIES AND DATASET

# %%
#IMPORTING NECESSARY LIBRARIES FOR THE DATA PREPROCESSING
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#DATASET
df=pd.read_csv("/content/House Price India.csv")
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df.tail()
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 14615  6762830250  42734                   2                  1.5
# 14616  6762830339  42734                   3                  2.0
# 14617  6762830618  42734                   2                  1.0
# 14618  6762830709  42734                   4                  1.0
# 14619  6762831463  42734                   3                  1.0
#
#        living area  lot area  number of floors  waterfront present  \
# 14615         1556     20000               1.0                   0
# 14616         1680      7000               1.5                   0
# 14617         1070      6120               1.0                   0
# 14618         1030      6621               1.0                   0
# 14619          900      4770               1.0                   0
#
#        number of views  condition of the house  ...  Built Year  \
# 14615                0                       4  ...        1957
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %% [markdown]
# # CHECKING FOR NULL AND DUPLICATE VLAUES

# %%
df.isna().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **THERE ARE NO NULL AND DUPLICATE VALUES IN OUR DATASET**

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %% [markdown]
# **By observing the above table, we can conclude that outliers are present in our dataset(max>>>75%).**

# %% [markdown]
# ** **

# %% [markdown]
# **CATEGORICAL COLUMNS**

# %%
df["number of bedrooms"].value_counts()
# Out:
# 3     6612
# 4     4724
# 2     1844
# 5     1079
# 6      176
# 1      136
# 7       30
# 8       11
# 9        3
# 10       3
# 33       1
# 11       1
# Name: number of bedrooms, dtype: int64

# %%
df["number of bedrooms"].value_counts().plot(kind="bar")
plt.xlabel("No of Bedrooms")
plt.ylabel("Total no of Bedrooms")
plt.show()

# %% [markdown]
# **3 BEDROOMS HAS THE HIGHEST COUNT.**

# %%
df["number of bathrooms"].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# **2.5 BATHROOMS HAS THE HIGHEST COUNT.**

# %%
sns.countplot(x="waterfront present",data=df)
# Out:
# <Axes: xlabel='waterfront present', ylabel='count'>

# %%
df["Number of schools nearby"].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Number of schools nearby'>

# %%
df["condition of the house"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# **CONDITION-3 HAS THE HIGHEST COUNT.**

# %%
plt.figure(figsize=(12,18))
sns.countplot(data=df,y='Built Year')
plt.show()

# %% [markdown]
# **MOST OF THE HOUSES WERE BUILT IN 2014**

# %%
plt.figure(figsize=(12,18))
sns.countplot(data=df,y='Postal Code')
plt.show()

# %% [markdown]
# **MOST OF THE HOUSES LISTED FOR SALE ARE FROM THE PINCODE 122028.**

# %% [markdown]
# # BIVARIATE ANALYSIS

# %%
plt.figure(figsize=(12,8))
sns.barplot(x=df['number of bedrooms'], y=df['Price'])
plt.show()

# %% [markdown]
# ****

# %% [markdown]
# **FROM THE ABOVE BARPLOT, WE CAN SEE THAT THE HOUSE WITH 8 BEDROOMS HAS THE HIGHEST COST THAN OTHER HOUSES.**

# %%
sns.barplot(x=df['condition of the house'], y=df['Price'])
# Out:
# <Axes: xlabel='condition of the house', ylabel='Price'>

# %%
sns.barplot(x=df['waterfront present'], y=df['Price'])
# Out:
# <Axes: xlabel='waterfront present', ylabel='Price'>

# %% [markdown]
# **WATER FRONT PRESENT INFLUENCES OUR DEPENDENT FEATURE("Price")**

# %%
sns.barplot(x=df['condition of the house'], y=df['Built Year'])
# Out:
# <Axes: xlabel='condition of the house', ylabel='Built Year'>

# %%
#sns.pairplot(df,hue="Price")

# %% [markdown]
# # MULTIVARIATE ANALYSIS

# %%
plt.figure(figsize=(18,8))
sns.heatmap(df.corr(),cmap="Blues",annot=True)
plt.show()

# %%
#DROPPING UNNECESSARY COLUMNS
df.drop(["id","Postal Code","Date"],axis=1,inplace=True)

# %%
plt.figure(figsize=(18,8))
sns.heatmap(df.corr(),cmap="Blues",annot=True)
plt.show()

# %% [markdown]
# **As you can see columns like 'lot area', 'condition of the house', 'Built Year', 'lot_area_renov', 'Number of schools nearby', 'Distance from the airport', 'Longitude' contribute minimal to Price which is the Target variable.**
